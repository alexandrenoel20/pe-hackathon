# %%
print('hello world')
# Out:
# hello world

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('coiffeurs.xlsx')
df = df.dropna()
df
# Out:
#           type                      nom        lat       lng  num  \
# 0      Feature  Tete En L'hair Coiffure  49.181161 -0.376700   50
# 2      Feature              Imagina'tif  47.268834  5.010264   11
# 4      Feature              Berang'hair  45.840027  5.029739  319
# 6      Feature                 Jad Hair  43.105707  5.863404  199
# 8      Feature              Namast'hair  49.363735  3.460229   12
# ...        ...                      ...        ...       ...  ...
# 12424  Feature        Un Hair De Beaute  47.873159  4.543366   29
# 12426  Feature           Maiatmosf'hair  48.588969  2.564031  135
# 12428  Feature             Atmosph'hair  45.516250  2.372685    6
# 12430  Feature               L'hair Zen  48.352284 -1.196357   13
# 12432  Feature              Planet'hair  48.376344 -4.643738    1
#
#                           voie                     ville codepostal  \
# 0                RUE CAPONIERE                      CAEN      14000
# ...

# %%
#Corrélation Nord-Sud :
#Données : Plus haute latitude France : 51.05 ; Plus basse latitude France : 41.22 
categorieLatitude = pd.cut(df['lat'], bins=[41.22 + k*0.25 for k in range (40)], labels = [str(i) for i in range(39)])
df['CateLat'] = categorieLatitude
L = df.groupby(['CateLat']).size()
L
# Out:
# C:\Users\antoi\AppData\Local\Temp\ipykernel_14736\3280477486.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   L = df.groupby(['CateLat']).size()
# CateLat
# 0       2
# 1       0
# 2       4
# 3       0
# 4       0
# 5      47
# 6      15
# 7     128
# 8     241
# 9     321
# 10    168
# 11     86
# 12     59
# 13     54
# 14    102
# 15    154
# 16    122
# 17    179
# 18    238
# 19    152
# 20    117
# 21     91
# 22    119
# 23    161
# 24    217
# 25    179
# 26    223
# 27    200
# 28    186
# 29    306
# 30    410
# 31    246
# 32    194
# 33    146
# 34     83
# 35     89
# 36    142
# 37    154
# 38     60
# dtype: int64

# %%
fig = plt.figure()
X = [ 41.22 + k*0.25 for k in range (39)]
x = X
height = L
width = 1.0

plt.bar(x, height, width, color='b')
plt.title('Nombre de coiffeurs drôles en fonction de la latitude')
plt.show()

# %%
categorieLongitude = pd.cut(df['lng'], bins=[4.47 + k*0.1 for k in range (37)], labels = [str(i) for i in range(36)])
df['CateLng'] = categorieLongitude
M = df.groupby(['CateLng']).size()
M
# Out:
# C:\Users\antoi\AppData\Local\Temp\ipykernel_14736\2748388927.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   M = df.groupby(['CateLng']).size()
# CateLng
# 0      26
# 1      50
# 2      80
# 3     123
# 4      72
# 5      84
# 6      44
# 7      48
# 8      51
# 9      79
# 10     41
# 11     32
# 12     57
# 13     53
# 14     81
# 15     67
# 16     91
# 17     47
# 18     40
# 19     36
# 20     43
# 21     44
# 22     50
# 23     41
# 24     30
# 25     27
# 26     42
# 27     36
# 28     52
# 29     22
# 30     31
# 31     13
# 32     30
# 33     14
# 34      2
# 35      4
# dtype: int64

# %%
fig2 = plt.figure()
X = [4.47 + k*0.1 for k in range (36)]
x = X
height = M
width = 1.0

plt.bar(x, height, width, color='b')
plt.title('Nombre de coiffeurs drôles en fonction de la longitude')
plt.show()
